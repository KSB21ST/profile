# %%
import os
import sys
import time
import datetime
from PIL import Image
import cv2
import matplotlib.pyplot as plt
import numpy as np
import math
import torch
import torch.nn as nn
from torchvision.utils import save_image, make_grid
import torchvision.transforms as transforms
import glob


# !rm /etc/localtime
# !ln -s /usr/share/zoneinfo/Asia/Seoul /etc/localtime

# %%
from google.colab import drive
drive.mount("/content/drive")

# Autoreload in case that the custom modules are changed
# %load_ext autoreload
# %autoreload 2
# Out:
# Mounted at /content/drive

# %%
filepath = "/content/drive/MyDrive/Colab Notebooks/coe202final"

sys.path.append(filepath)

from util import *
# from model_baseline import *
from UNet_L4_ASPP import *

# %%
# Class information
classes = ['background',
'aeroplane',
'bicycle',
'boat',
'bus',
'car',
'motorbike',
'person',
'train',
'boundary'] # For convenience, the classes are denoted as corresponding indexes (0~9) in this script.
# We ignore the boundary class (index : 9) in this project!

image_transform = transforms.ToPILImage() # converting Torch.tensor -> PIL format

# You can freely add or modify any transform functions,
# except ToTensor, ToLabel, Relabel functions (again, do not change!).

common_transform = []

input_transform = [transforms.ToTensor()]

target_transform = [ToLabel(),
    Relabel(4, 3),
    Relabel(6, 4),
    Relabel(7, 5),
    Relabel(14, 6),
    Relabel(15, 7),
    Relabel(19, 8),
    Relabel(255, 9),
]

input_transform = transforms.Compose(common_transform + input_transform)
target_transform = transforms.Compose(common_transform + target_transform)

# %%
# You can modify the loss, the model and the optimizer
criterion = nn.CrossEntropyLoss(ignore_index=9).cuda() # Ignore the index 9 indiciating 'boundaries' for calculating loss
model = UNet().cuda()
experiment = "exp_colab"

os.makedirs(f"{filepath}/{experiment}/eval_result", exist_ok=True)

model.load_state_dict(torch.load(f"{filepath}/best_model_state_dict.pt"))

model.eval()

print("Loaded.")
# Out:
# Loaded.

# %%
# Specify the path of evaluation data folder.
evaldata_path = "/content/drive/MyDrive/Colab Notebooks/coe202final/CoE202Spring_finalproject_dataset/Images"
eval_paths = glob.glob(f"{evaldata_path}/*.jpg")

# %%
# Make color palette for visualization. Image will be saved containing [0, 1, ... 9] labels. With this palette, we can view with color for corresponding label.
import matplotlib.pyplot as plt

squares = torch.arange(10).unsqueeze(0)
plt.imshow(squares.numpy(), cmap='tab10')
a = plt.get_cmap('tab10')

colors = torch.zeros(10, 3)
for i in range(1, 10):
    colors[i, :] = torch.tensor(list(a(i)[:3]))
colors = colors * 255
colors = colors.int().numpy().astype("uint8")
print(colors)
# Out:
# [[  0   0   0]
#  [255 127  14]
#  [ 44 160  44]
#  [214  39  40]
#  [148 103 189]
#  [140  86  75]
#  [227 119 194]
#  [127 127 127]
#  [188 189  34]
#  [ 23 190 207]]

# %% [markdown]
# ### **Coloring example**

# %%
# Because we will use except boundary
colors = colors[:9]

dataset = CoE_Dataset(root=f"{filepath}/CoE202Spring_finalproject_dataset", # root should be the path of your test dataset
                input_transform=input_transform,
                target_transform=target_transform)

print('Total number of images : {}'.format(len(dataset)))


# ------------
# Load dataset
# ------------

loader = torch.utils.data.DataLoader(dataset,
                                    batch_size=1,
                                    shuffle=True,
                                    drop_last=True
                                    )

fig = plt.figure(figsize=(12, 14))
for i in range(2):
    for j in range(2):
        (sample_batch, sample_label, _) = next(iter(loader))
        fig.add_subplot(4, 4, (i * 4 + j * 2 + 1))
        plt.imshow(sample_batch[0].permute(1, 2, 0))
        classes_name = [classes[index] for index in torch.unique(sample_label[0]) if not index == 9]
        plt.title('class : ' + str(classes_name))
        fig.add_subplot(4, 4, (i * 4 + j * 2 + 1+ 1))

        r = Image.fromarray(sample_label[0][0].byte().cpu().numpy())
        r.putpalette(colors)
        r.convert('RGB')
        plt.imshow(r)
plt.suptitle("Sample images")
# Out:
# Total number of images : 1000
# Text(0.5, 0.98, 'Sample images')

# %% [markdown]
# ### **EVALUATION**

# %%
# We will iterate the evaluation data and inference with loaded model.
# Predicted images will save in this path. "{filepath}/{experiment}/eval_result/"

# Because we will use except boundary
colors = colors[:9]

for eval_path in eval_paths:
    name = eval_path.split('/')[-1].split('.')[0]
    img = Image.open(eval_path)
    img = input_transform(img).unsqueeze(0)
    print(f"name : {name}, Size : {img.size()}")

    img = img.cuda()
    pred = model(img)

    pred = pred[0].max(0)[1].unsqueeze(0).detach()

    r = Image.fromarray(pred[0].byte().cpu().numpy())
    r.putpalette(colors)
    r.save(f"{filepath}/{experiment}/eval_result/{name}.png")
# Out:
# name : 3233569687, Size : torch.Size([1, 3, 341, 500])
# name : 3232561153, Size : torch.Size([1, 3, 375, 500])
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3672: UserWarning: nn.functional.upsample_bilinear is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.functional.upsample_bilinear is deprecated. Use nn.functional.interpolate instead.")
# name : 3233560897, Size : torch.Size([1, 3, 500, 333])
# name : 3233560130, Size : torch.Size([1, 3, 332, 500])
# name : 3233567210, Size : torch.Size([1, 3, 333, 500])
# name : 3232568551, Size : torch.Size([1, 3, 500, 379])
# name : 3244569100, Size : torch.Size([1, 3, 375, 500])
# name : 3233560089, Size : torch.Size([1, 3, 332, 500])
# name : 3231567113, Size : torch.Size([1, 3, 375, 500])
# name : 3233561678, Size : torch.Size([1, 3, 375, 500])
# name : 3233561528, Size : torch.Size([1, 3, 333, 500])
# name : 3232567568, Size : torch.Size([1, 3, 500, 321])
# name : 3232561859, Size : torch.Size([1, 3, 345, 500])
# name : 3231566481, Size : torch.Size([1, 3, 333, 500])
# name : 3244560922, Size : torch.Size([1, 3, 333, 500])
# name : 3231561899, Size : torch.Size([1, 3, 366, 500])
# name : 3245569247, Size : torch.Size([1, 3, 375, 500])
# name : 3232568294, Size : torch.Size([1, 3, 500, 333])
# name : 3244561563, Size : torch.Size([1, 3, 500, 375])
# name : 3231562701, Size : torch.Size([1, 3, 375, 500])
# name : 3244561832, Size : torch.Size([1, 3, 349, 500])
# name : 3232567260, Size : torch.Size([1, 3, 332, 500])
# name : 3232567523, Size : torch.Size([1, 3, 426, 320])
# name : 3232561870, Size : torch.Size([1, 3, 375, 500])
# name : 3231567319, Size : torch.Size([1, 3, 375, 500])
# name : 3233561443, Size : torch.Size([1, 3, 375, 500])
# name : 3244562511, Size : torch.Size([1, 3, 375, 500])
# name : 3232567155, Size : torch.Size([1, 3, 225, 300])
# name : 3244569153, Size : torch.Size([1, 3, 375, 500])
# name : 3232569059, Size : torch.Size([1, 3, 374, 500])
# name : 3244569472, Size : torch.Size([1, 3, 375, 500])
# name : 3233561672, Size : torch.Size([1, 3, 500, 385])
# name : 3244569322, Size : torch.Size([1, 3, 268, 500])
# name : 3231566701, Size : torch.Size([1, 3, 400, 500])
# name : 3233562821, Size : torch.Size([1, 3, 313, 500])
# name : 3231564145, Size : torch.Size([1, 3, 500, 375])
# name : 3232568064, Size : torch.Size([1, 3, 375, 500])
# name : 3244562223, Size : torch.Size([1, 3, 375, 500])
# name : 3233567635, Size : torch.Size([1, 3, 287, 500])
# name : 3233567534, Size : torch.Size([1, 3, 500, 333])
# name : 3232560766, Size : torch.Size([1, 3, 345, 500])
# name : 3244567719, Size : torch.Size([1, 3, 500, 334])
# name : 3231566929, Size : torch.Size([1, 3, 375, 500])
# name : 3232560729, Size : torch.Size([1, 3, 500, 375])
# name : 3233569704, Size : torch.Size([1, 3, 333, 500])
# name : 3232563044, Size : torch.Size([1, 3, 500, 374])
# name : 3232560776, Size : torch.Size([1, 3, 375, 500])
# name : 3231566805, Size : torch.Size([1, 3, 333, 500])
# name : 3244568994, Size : torch.Size([1, 3, 500, 355])
# name : 3232568830, Size : torch.Size([1, 3, 375, 500])
# name : 3231564605, Size : torch.Size([1, 3, 368, 500])
# name : 3244561970, Size : torch.Size([1, 3, 443, 500])
# name : 3233562946, Size : torch.Size([1, 3, 434, 500])
# name : 3232564091, Size : torch.Size([1, 3, 375, 500])
# name : 3231560981, Size : torch.Size([1, 3, 333, 500])
# name : 3232569173, Size : torch.Size([1, 3, 432, 324])
# name : 3231568111, Size : torch.Size([1, 3, 333, 500])
# name : 3244562156, Size : torch.Size([1, 3, 375, 500])
# name : 3233569107, Size : torch.Size([1, 3, 326, 500])
# name : 3244567985, Size : torch.Size([1, 3, 375, 500])
# name : 3233567709, Size : torch.Size([1, 3, 261, 500])
# name : 3245568923, Size : torch.Size([1, 3, 382, 500])
# name : 3231564025, Size : torch.Size([1, 3, 333, 500])
# name : 3244560064, Size : torch.Size([1, 3, 375, 500])
# name : 3231562158, Size : torch.Size([1, 3, 500, 334])
# name : 3231562649, Size : torch.Size([1, 3, 375, 500])
# name : 3232561148, Size : torch.Size([1, 3, 375, 500])
# name : 3232561002, Size : torch.Size([1, 3, 375, 500])
# name : 3231560666, Size : torch.Size([1, 3, 382, 500])
# name : 3233568731, Size : torch.Size([1, 3, 375, 500])
# name : 3232560171, Size : torch.Size([1, 3, 375, 500])
# name : 3245567787, Size : torch.Size([1, 3, 375, 500])
# name : 3244560558, Size : torch.Size([1, 3, 295, 500])
# name : 3233569907, Size : torch.Size([1, 3, 333, 500])
# name : 3232560119, Size : torch.Size([1, 3, 375, 500])
# name : 3232560593, Size : torch.Size([1, 3, 337, 500])
# name : 3245567245, Size : torch.Size([1, 3, 333, 500])
# name : 3232568996, Size : torch.Size([1, 3, 500, 375])
# name : 3232561612, Size : torch.Size([1, 3, 375, 500])
# name : 3231568074, Size : torch.Size([1, 3, 375, 500])
# name : 3231567823, Size : torch.Size([1, 3, 366, 500])
# name : 3245568404, Size : torch.Size([1, 3, 330, 500])
# name : 3244561104, Size : torch.Size([1, 3, 375, 500])
# name : 3231560933, Size : torch.Size([1, 3, 292, 500])
# name : 3233561416, Size : torch.Size([1, 3, 175, 500])
# name : 3233567618, Size : torch.Size([1, 3, 339, 500])
# name : 3232562128, Size : torch.Size([1, 3, 375, 500])
# name : 3244562433, Size : torch.Size([1, 3, 376, 500])
# name : 3232562528, Size : torch.Size([1, 3, 500, 333])
# name : 3245569787, Size : torch.Size([1, 3, 375, 500])
# name : 3232563855, Size : torch.Size([1, 3, 375, 500])
# name : 3232568356, Size : torch.Size([1, 3, 333, 500])
# name : 3231564563, Size : torch.Size([1, 3, 334, 500])
# name : 3232569037, Size : torch.Size([1, 3, 500, 326])
# name : 3245568279, Size : torch.Size([1, 3, 281, 500])
# name : 3233568196, Size : torch.Size([1, 3, 385, 500])
# name : 3232563313, Size : torch.Size([1, 3, 375, 500])
# name : 3232567435, Size : torch.Size([1, 3, 240, 320])
# name : 3231566408, Size : torch.Size([1, 3, 375, 500])
# name : 3245567442, Size : torch.Size([1, 3, 375, 500])
# name : 3233568306, Size : torch.Size([1, 3, 375, 500])
# name : 3232560666, Size : torch.Size([1, 3, 333, 500])
# name : 3232561704, Size : torch.Size([1, 3, 500, 375])
# name : 3231562071, Size : torch.Size([1, 3, 500, 330])
# name : 3233567615, Size : torch.Size([1, 3, 333, 500])
# name : 3232560986, Size : torch.Size([1, 3, 400, 500])
# name : 3233569677, Size : torch.Size([1, 3, 243, 500])
# name : 3233562868, Size : torch.Size([1, 3, 358, 500])
# name : 3244560705, Size : torch.Size([1, 3, 425, 500])
# name : 3232565042, Size : torch.Size([1, 3, 500, 375])
# name : 3232562418, Size : torch.Size([1, 3, 333, 500])
# name : 3232568298, Size : torch.Size([1, 3, 375, 500])
# name : 3244567161, Size : torch.Size([1, 3, 269, 500])
# name : 3244567028, Size : torch.Size([1, 3, 333, 500])
# name : 3245567664, Size : torch.Size([1, 3, 313, 500])
# name : 3232562427, Size : torch.Size([1, 3, 375, 500])
# name : 3245569940, Size : torch.Size([1, 3, 375, 500])
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-2a31b2794673> in <module>()
#      18     r = Image.fromarray(pred[0].byte().cpu().numpy())
#      19     r.putpalette(colors)
# ---> 20     r.save(f"{filepath}/{experiment}/eval_result/{name}.png")
#
# /usr/local/lib/python3.7/dist-packages/PIL/Image.py in save(self, fp, format, **params)
#    2129                 fp = builtins.open(filename, "r+b")
#    2130             else:
# -> 2131                 fp = builtins.open(filename, "w+b")
#    2132
#    2133         try:
#
# KeyboardInterrupt:

# %%
# While we can see the images with color, actual value of the image is within [0~8] value.
C = np.array(Image.open(f"{filepath}/eval_result/{name}.png").convert('P'))
np.unique(C)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-13-a4850a19c02b> in <module>()
#       1 # While we can see the images with color, actual value of the image is within [0~8] value.
# ----> 2 C = np.array(Image.open(f"{filepath}/eval_result/{name}.png").convert('P'))
#       3 np.unique(C)
#
# /usr/local/lib/python3.7/dist-packages/PIL/Image.py in open(fp, mode)
#    2841
#    2842     if filename:
# -> 2843         fp = builtins.open(filename, "rb")
#    2844         exclusive_fp = True
#    2845
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/Colab Notebooks/coe202final/eval_result/3245569940.png'
